# %% [markdown]
# <a href="https://colab.research.google.com/github/Anitha-Naresh/PYTHON---ASSIGNMENT-3/blob/main/Python_assignment_3rd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
secret_number = random.randint(1, 10)

print("A secret number has been generated between 1 and 10.")
# Out:
# A secret number has been generated between 1 and 10.

# %%
attempts = 3

print("You have", attempts, "attempts to guess the number.")
# Out:
# You have 3 attempts to guess the number.

# %%
while attempts > 0:

    guess = int(input("Guess the number (between 1 and 10): "))

    # Check if the guess is within the valid range
    if guess < 1 or guess > 10:
        print("Your guess is out of range. Please guess a number between 1 and 10.")
        continue

    # Reduce the number of attempts
    attempts -= 1

    # Check the guess
    if guess == secret_number:
        print("Congratulations! You guessed the correct number.")
        break

    elif guess > secret_number:
        print("Too high. Try again.")

    else:
        print("Too low. Try again.")

else:
    print("Better luck next time!")
    print("The secret number was:", secret_number)
# Out:
# Guess the number (between 1 and 10): 7
# Too low. Try again.
# Guess the number (between 1 and 10): 4
# Too low. Try again.
# Guess the number (between 1 and 10): 3
# Too low. Try again.
# Better luck next time!
# The secret number was: 9

# %%
number = int(input("Enter the number for which you want the multiplication table: "))
# Out:
# Enter the number for which you want the multiplication table: 5

# %%
for i in range(1, 11):

    result = number * i

    print(f"{number} x {i} = {result}")
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
number = int(input("Enter the number for which you want the multiplication table: "))

for i in range(1, 11):

    result = number * i

    print(f"{number} x {i} = {result}")
# Out:
# Enter the number for which you want the multiplication table: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
def calculate_bmi(weight, height):
    bmi = weight / (height ** 2)
    return bmi

weight = float(input("Enter your weight in kg: "))
height = float(input("Enter your height in meters: "))

bmi = calculate_bmi(weight, height)

print("Your BMI is:", round(bmi, 2))
# Out:
# Enter your weight in kg: 87
# Enter your height in meters: 6
# Your BMI is: 2.42
